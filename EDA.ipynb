# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

#machine learning tools
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.calibration import CalibratedClassifierCV
from sklearn.metrics import classification_report, confusion_matrix

#models and balancing
from xgboost import XGBClassifier #XGBoost is our main prediction model.
from imblearn.over_sampling import SMOTE #SMOTE helps balance the dataset (since failures are rare).

#Set Randomness for reproducibility
np.random.seed(42)

# %%
df = pd.read_csv("Data\dataset.csv")
df.head(15)
# Out:
#     UDI Product ID Type  Air temperature [K]  Process temperature [K]  ...  TWF  HDF  PWF  OSF  RNF
# 0     1     M14860    M                298.1                    308.6  ...    0    0    0    0    0
# 1     2     L47181    L                298.2                    308.7  ...    0    0    0    0    0
# 2     3     L47182    L                298.1                    308.5  ...    0    0    0    0    0
# 3     4     L47183    L                298.2                    308.6  ...    0    0    0    0    0
# 4     5     L47184    L                298.2                    308.7  ...    0    0    0    0    0
# 5     6     M14865    M                298.1                    308.6  ...    0    0    0    0    0
# 6     7     L47186    L                298.1                    308.6  ...    0    0    0    0    0
# 7     8     L47187    L                298.1                    308.6  ...    0    0    0    0    0
# ...

# %%
# Label Encoding
df['Type'] = LabelEncoder().fit_transform(df['Type'])

# %%
df.head(15)
# Out:
#     UDI Product ID  Type  Air temperature [K]  Process temperature [K]  ...  TWF  HDF  PWF  OSF  RNF
# 0     1     M14860     2                298.1                    308.6  ...    0    0    0    0    0
# 1     2     L47181     1                298.2                    308.7  ...    0    0    0    0    0
# 2     3     L47182     1                298.1                    308.5  ...    0    0    0    0    0
# 3     4     L47183     1                298.2                    308.6  ...    0    0    0    0    0
# 4     5     L47184     1                298.2                    308.7  ...    0    0    0    0    0
# 5     6     M14865     2                298.1                    308.6  ...    0    0    0    0    0
# 6     7     L47186     1                298.1                    308.6  ...    0    0    0    0    0
# 7     8     L47187     1                298.1                    308.6  ...    0    0    0    0    0
# ...

# %%
# High Q - 0 
# Low Q - 1
# Medium Q - 2
